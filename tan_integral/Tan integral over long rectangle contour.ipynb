# %% [markdown]
# # Tan integral over long rectangle contour

# %%
from sympy import *

# %%
x, y, n, m, K, k, epsilon, z, s, a, R, N, L, t = symbols('x, y, n, m, K, k, epsilon, z, s, a, R, N, L, t')
alpha, beta, delta, mu, nu, epsilon, theta, tau = symbols('alpha, beta, delta, mu, nu, epsilon, theta, tau')

# %%
diff(1/(n+alpha)**s, s)
# Out:
# -(alpha + n)**(-s)*log(alpha + n)

# %%
Integral(1/(1+x**2)*1/(1+tan(x)), (x, 0, pi/2)).evalf()
# Out:
# 0.597381809451804

# %%
(atan(pi/2)/2 + Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4))).evalf()
# Out:
# 0.597381809451804

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4))
# Out:
# Integral((-1/(2*((x + pi/4)**2 + 1)) + 1/(2*((x - pi/4)**2 + 1)))*tan(x), (x, 0, pi/4))

# %%
diff(Integral(tan((x+tau)*y)/(x+tau),x),y).doit()
# Out:
# Integral(tan(y*(tau + x))**2 + 1, x)

# %%
plot((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,-pi/2+0.1,pi/2-0.1))

# %%
pi*Integral((1/(16+(x-1)**2*pi**2)-1/(16+(x+1)**2*pi**2))*tan(x*pi/4),(x,-1,1))
# Out:
# pi*Integral((-1/(pi**2*(x + 1)**2 + 16) + 1/(pi**2*(x - 1)**2 + 16))*tan(pi*x/4), (x, -1, 1))

# %%
Integral((1/(tau**2+(x-1)**2)-1/(tau**2+(x+1)**2))*tan(x/tau),(x,-1,1))/pi
# Out:
# Integral((-1/(tau**2 + (x + 1)**2) + 1/(tau**2 + (x - 1)**2))*tan(x/tau), (x, -1, 1))/pi

# %%
(atan(pi/2)/2 + Integral((1/(tau**2+(x-1)**2)-1/(tau**2+(x+1)**2))*tan(x/tau),(x,-1,1))/pi).subs(tau,4/pi).evalf()
# Out:
# 0.597381809451804

# %%
Eq(tau,4/pi)
# Out:
# Eq(tau, 4/pi)

# %%
(Integral((1/(tau**2+(x-1)**2)-1/(tau**2+(x+1)**2))*tan(x/tau),(x,-1,1))/pi).subs(tau, 4/pi).evalf()
# Out:
# 0.0954393985248599

# %%
(pi*Integral((1/(16+(x-1)**2*pi**2)-1/(16+(x+1)**2*pi**2))*tan(x*pi/4),(x,-1,1))).evalf()
# Out:
# 0.0954393985248599

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4)).evalf()
# Out:
# 0.0954393985248599

# %%
f_tau = (1/(tau**2+(x-1)**2)-1/(tau**2+(x+1)**2))*tan(x/tau)

# %%
from sympy.plotting import plot3d
plot3d(abs(f_tau).subs([(x,x+I*y),(tau,4/pi)]),(x, -1, 1), (y, 0, 10))

# %%
plot(f_tau.subs(tau,4/pi),(x,-1,1))

# %%
f_tau
# Out:
# (-1/(tau**2 + (x + 1)**2) + 1/(tau**2 + (x - 1)**2))*tan(x/tau)

# %%
tan(4*pi/2)
# Out:
# 0

# %%
Eq(x,tau*pi*(2*n+1)/2)
# Out:
# Eq(x, pi*tau*(2*n + 1)/2)

# %%
Eq(x,tau*pi*(2*n+1)/2).subs(tau,4/pi)
# Out:
# Eq(x, 4*n + 2)

# %%
Eq(tau**2 +(x+1)**2,0)
# Out:
# Eq(tau**2 + (x + 1)**2, 0)

# %%
Eq((I*tau + x + 1)*(-I*tau + x + 1),0)
# Out:
# Eq((-I*tau + x + 1)*(I*tau + x + 1), 0)

# %%
Eq(x,-1+I*tau)
# Out:
# Eq(x, I*tau - 1)

# %%
Eq(x,-1-I*tau)
# Out:
# Eq(x, -I*tau - 1)

# %%
Eq((I*tau + x - 1)*(-I*tau + x - 1),0)
# Out:
# Eq((-I*tau + x - 1)*(I*tau + x - 1), 0)

# %%
Eq(x,1+I*tau)
# Out:
# Eq(x, I*tau + 1)

# %%
Eq(x,1-I*tau)
# Out:
# Eq(x, -I*tau + 1)

# %%
Eq(Limit((z-(I*tau-1))*f_tau.subs(x,z),z,I*tau-1), limit((z-(I*tau-1))*f_tau.subs(x,z),z,I*tau-1))
# Out:
# Eq(Limit((-1/(tau**2 + (z + 1)**2) + 1/(tau**2 + (z - 1)**2))*(-I*tau + z + 1)*tan(z/tau), z, I*tau - 1), I*tan(I - 1/tau)/(2*tau))

# %%
Eq(Limit((z-(I*tau+1))*f_tau.subs(x,z),z,I*tau+1), limit((z-(I*tau+1))*f_tau.subs(x,z),z,I*tau+1))
# Out:
# Eq(Limit((-1/(tau**2 + (z + 1)**2) + 1/(tau**2 + (z - 1)**2))*(-I*tau + z - 1)*tan(z/tau), z, I*tau + 1), -I*tan(I + 1/tau)/(2*tau))

# %%
(atan(pi/2)/2 + I*(I*tan(I-1/tau)/(2*tau)-I*tan(I+1/tau)/(2*tau)).subs(tau,4/pi)).evalf()
# Out:
# 0.710702993280178 + 2.58493941422821e-26*I

# %%
f_tau.subs(x,x+I*y)
# Out:
# (-1/(tau**2 + (x + I*y + 1)**2) + 1/(tau**2 + (x + I*y - 1)**2))*tan((x + I*y)/tau)

# %%
Eq(tan(x), I-2*I/(1+exp(-2*I*x)))
# Out:
# Eq(tan(x), I - 2*I/(1 + exp(-2*I*x)))

# %%
Eq(tan(x), I-2*I/(1+exp(-2*I*x))).subs(x,(x+I*y)/tau).expand()
# Out:
# Eq(tan(x/tau + I*y/tau), I - 2*I/(exp(2*y/tau)*exp(-2*I*x/tau) + 1))

# %%
Eq(Limit(tan(x/tau+I*y/tau),y,oo).subs(tau,4/pi),Limit(tan(x/tau+I*y/tau),y,oo).subs(tau,4/pi).doit())
# Out:
# Eq(Limit(tan(pi*x/4 + I*pi*y/4), y, oo, dir='-'), I)

# %%
limit(f_tau.subs(x,x+I*y)/(tan((x+I*y)/tau)),y,oo)
# Out:
# 0

# %%
f_tau.subs(x,-1+I*y)
# Out:
# (1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau)

# %%
f_tau.subs(x,1+I*y)
# Out:
# (-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau)

# %%
Integral(f_tau.subs(x,1+I*y),(y,0,L)) + Integral(f_tau.subs(x,-1+I*y),(y,L,0))
# Out:
# Integral((1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, L, 0)) + Integral((-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, 0, L))

# %%
Integral(f_tau.subs(x,1+I*y),(y,0,L)) - Integral(f_tau.subs(x,-1+I*y),(y,0,L))
# Out:
# -Integral((1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, 0, L)) + Integral((-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, 0, L))

# %%
(Integral(f_tau.subs(x,1+I*y),(y,0,L))).subs([(L,1),(tau,4/pi)]).evalf()
# Out:
# 0.407614768737275 + 0.48708833349818*I

# %%
( - Integral(f_tau.subs(x,-1+I*y),(y,0,L))).subs([(L,1),(tau,4/pi)]).evalf()
# Out:
# -0.407614768737275 + 0.48708833349818*I

# %%
4/pi
# Out:
# 4/pi

# %%
f_tau.subs(x,z).subs(z,-1+I*tau+epsilon*exp(-I*theta))
# Out:
# (1/(tau**2 + (epsilon*exp(-I*theta) + I*tau - 2)**2) - 1/(tau**2 + (epsilon*exp(-I*theta) + I*tau)**2))*tan((epsilon*exp(-I*theta) + I*tau - 1)/tau)

# %%
exp(-I*theta).subs(theta,pi/2)
# Out:
# -I

# %%
Integral(-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,-1+I*tau+epsilon*exp(-I*theta)),(theta,-pi/2,pi/2))
# Out:
# Integral(-I*epsilon*(1/(tau**2 + (epsilon*exp(-I*theta) + I*tau - 2)**2) - 1/(tau**2 + (epsilon*exp(-I*theta) + I*tau)**2))*exp(-I*theta)*tan((epsilon*exp(-I*theta) + I*tau - 1)/tau), (theta, -pi/2, pi/2))

# %%
Integral(-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,1+I*tau+epsilon*exp(-I*theta)),(theta,pi/2,3*pi/2))
# Out:
# Integral(-I*epsilon*(-1/(tau**2 + (epsilon*exp(-I*theta) + I*tau + 2)**2) + 1/(tau**2 + (epsilon*exp(-I*theta) + I*tau)**2))*exp(-I*theta)*tan((epsilon*exp(-I*theta) + I*tau + 1)/tau), (theta, pi/2, 3*pi/2))

# %%
limit((-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,-1+I*tau+epsilon*exp(-I*theta))),epsilon,0)
# Out:
# tan(I - 1/tau)/(2*tau)

# %%
Eq(Integral(tan(I-1/tau)/2/tau,(theta,-pi/2,pi/2)),Integral(tan(I-1/tau)/2/tau,(theta,-pi/2,pi/2)).doit())
# Out:
# Eq(Integral(tan(I - 1/tau)/(2*tau), (theta, -pi/2, pi/2)), pi*tan(I - 1/tau)/(2*tau))

# %%
limit(-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,1+I*tau+epsilon*exp(-I*theta)),epsilon,0)
# Out:
# -tan(I + 1/tau)/(2*tau)

# %%
Eq(Integral(-tan(I+1/tau)/2/tau,(theta,pi/2,3*pi/2)),Integral(-tan(I+1/tau)/2/tau,(theta,pi/2,3*pi/2)).doit())
# Out:
# Eq(Integral(-tan(I + 1/tau)/(2*tau), (theta, pi/2, 3*pi/2)), -pi*tan(I + 1/tau)/(2*tau))

# %%
(Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4)) - pi**2*tan(I+pi/4)/8 + pi**2*tan(I-pi/4)/8).evalf()
# Out:
# -0.560401313355189 + 0.e-20*I

# %% [markdown]
# ## Contour Integral Over Rectangle in Upper Half Plane Counter Clockwise

# %% [markdown]
# ### Part 1

# %%
part_1 = Integral(f_tau,(x,-1,1))
part_1
# Out:
# Integral((-1/(tau**2 + (x + 1)**2) + 1/(tau**2 + (x - 1)**2))*tan(x/tau), (x, -1, 1))

# %% [markdown]
# ### Part 2

# %%
part_2 = Integral(I*f_tau.subs(x,1+I*y),(y,0,L))
part_2
# Out:
# Integral(I*(-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, 0, L))

# %% [markdown]
# #### Part 2a

# %%
part_2a = Integral(I*f_tau.subs(x,1+I*y),(y,0,tau-epsilon))
part_2a
# Out:
# Integral(I*(-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, 0, -epsilon + tau))

# %% [markdown]
# #### Part 2b

# %%
part_2b= Integral(-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,1+I*tau+epsilon*exp(-I*theta)),(theta,pi/2,3*pi/2))
part_2b
# Out:
# Integral(-I*epsilon*(-1/(tau**2 + (epsilon*exp(-I*theta) + I*tau + 2)**2) + 1/(tau**2 + (epsilon*exp(-I*theta) + I*tau)**2))*exp(-I*theta)*tan((epsilon*exp(-I*theta) + I*tau + 1)/tau), (theta, pi/2, 3*pi/2))

# %% [markdown]
# #### Part 2c

# %%
part_2c = Integral(I*f_tau.subs(x,1+I*y),(y,tau+epsilon,L))
part_2c
# Out:
# Integral(I*(-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, epsilon + tau, L))

# %% [markdown]
# ### Part 3

# %%
part_3 = Integral(f_tau.subs(x,x+I*L),(x,1,-1))
part_3
# Out:
# Integral((-1/(tau**2 + (I*L + x + 1)**2) + 1/(tau**2 + (I*L + x - 1)**2))*tan((I*L + x)/tau), (x, 1, -1))

# %% [markdown]
# ### Part 4

# %%
part_4 = Integral(I*f_tau.subs(x,-1+I*y),(y,L,0)) 
part_4
# Out:
# Integral(I*(1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, L, 0))

# %% [markdown]
# #### Part 4a

# %%
part_4a = Integral(I*f_tau.subs(x,-1+I*y),(y,L,tau+epsilon)) 
part_4a
# Out:
# Integral(I*(1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, L, epsilon + tau))

# %% [markdown]
# #### Part 4b

# %%
part_4b = Integral(-I*epsilon*exp(-I*theta)*f_tau.subs(x,z).subs(z,-1+I*tau+epsilon*exp(-I*theta)),(theta,-pi/2,pi/2))
part_4b
# Out:
# Integral(-I*epsilon*(1/(tau**2 + (epsilon*exp(-I*theta) + I*tau - 2)**2) - 1/(tau**2 + (epsilon*exp(-I*theta) + I*tau)**2))*exp(-I*theta)*tan((epsilon*exp(-I*theta) + I*tau - 1)/tau), (theta, -pi/2, pi/2))

# %% [markdown]
# #### Part 4c

# %%
part_4c = Integral(I*f_tau.subs(x,-1+I*y),(y,tau-epsilon,0)) 
part_4c
# Out:
# Integral(I*(1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, -epsilon + tau, 0))

# %%
_subs = [(L,1),(tau,(4/pi)),(epsilon,0.00002)]
_subs
# Out:
# [(L, 1), (tau, 4/pi), (epsilon, 2e-05)]

# %%
(
    part_1.subs(_subs).evalf() +
    part_2a.subs(_subs).evalf() +
    part_2b.subs(_subs).evalf() +
    part_2c.subs(_subs).evalf() +
    part_3.subs(_subs).evalf() +
    part_4a.subs(_subs).evalf() +
    part_4b.subs(_subs).evalf() +
    part_4c.subs(_subs).evalf()
).simplify()
# Out:
# 1.77635683940025e-15

# %%
(0.655844345135481)/0.451452030391614
# Out:
# 1.4527442584909098

# %%
(
    Integral((f_tau/pi),(x,-1,1)).subs(_subs).evalf() +
    I*Integral((f_tau/pi).subs(x,1+I*y),(y,0,L)).subs(_subs).evalf() +
    Integral((f_tau/pi).subs(x,x+I*L),(x,1,-1)).subs(_subs).evalf() +
    I*Integral((f_tau/pi).subs(x,-1+I*y),(y,L,0)).subs(_subs).evalf()
).simplify()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1364     try:
# -> 1365         rf = evalf_table[x.func]
#    1366         r = rf(x, prec, options)
#
# KeyError: tan
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-04e3f9c9d539> in <module>
# ...

# %%
from sympy.plotting import plot3d
plot3d(abs(f_tau).subs([(x,x+I*y),(tau,4/pi)]),(x, -1, 1), (y, 0, 1))

# %%
(
    part_2a.subs(_subs).evalf() +
    part_2c.subs(_subs).evalf()
).simplify()
# Out:
# 0.178006315901377 + 0.060623824231091*I

# %%
(
    part_4a.subs(_subs).evalf() +
    part_4c.subs(_subs).evalf()
).simplify()
# Out:
# 0.178006315901377 - 0.060623824231091*I

# %%
(
    part_3.subs(_subs).evalf()
).simplify()
# Out:
# 6.39999980602305e-11 - 0.e-37*I

# %%
part_2
# Out:
# Integral(I*(-1/(tau**2 + (I*y + 2)**2) + 1/(tau**2 - y**2))*tan((I*y + 1)/tau), (y, 0, L))

# %%
part_4
# Out:
# Integral(I*(1/(tau**2 + (I*y - 2)**2) - 1/(tau**2 - y**2))*tan((I*y - 1)/tau), (y, L, 0))

# %%
part_4_also = Integral(-I*f_tau.subs(x,-1-I*y),(y,-L,0))
part_4_also
# Out:
# Integral(I*(1/(tau**2 + (-I*y - 2)**2) - 1/(tau**2 - y**2))*tan(-(-I*y - 1)/tau), (y, -L, 0))

# %%
(
    part_2.subs(_subs).evalf()
).simplify()
# Out:
# -0.48708833349818 + 0.407614768737275*I

# %%
(
    part_4.subs(_subs).evalf()
).simplify()
# Out:
# -0.48708833349818 - 0.407614768737275*I

# %%
(
    part_4_also.subs(_subs).evalf()
).simplify()
# Out:
# -0.48708833349818 - 0.407614768737275*I

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4))
# Out:
# Integral((-1/(2*((x + pi/4)**2 + 1)) + 1/(2*((x - pi/4)**2 + 1)))*tan(x), (x, 0, pi/4))

# %%
Eq(tan(theta), (I*(exp(-I*theta)-exp(I*theta))/(exp(I*theta)+exp(-I*theta))))
# Out:
# Eq(tan(theta), I*(-exp(I*theta) + exp(-I*theta))/(exp(I*theta) + exp(-I*theta)))

# %%
f_tau.subs(x,I*y)
# Out:
# I*(-1/(tau**2 + (I*y + 1)**2) + 1/(tau**2 + (I*y - 1)**2))*tanh(y/tau)

# %% [markdown]
# ## Contour integral over unit circle

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,0,pi/4))
# Out:
# Integral((-1/(2*((x + pi/4)**2 + 1)) + 1/(2*((x - pi/4)**2 + 1)))*tan(x), (x, 0, pi/4))

# %%
Integral((1/(16+(x-pi)**2)-1/(16+(x+pi)**2))*tan(x/4),(x,-pi,pi))
# Out:
# Integral((-1/((x + pi)**2 + 16) + 1/((x - pi)**2 + 16))*tan(x/4), (x, -pi, pi))

# %%
Integral((1/(16+(x-pi)**2)-1/(16+(x+pi)**2))*tan(x/4),(x,-pi,pi)).evalf()
# Out:
# 0.0954393985248599

# %%
fz = (-1/(-(ln(z)+ln(-1))**2 + 16) + 1/(-(ln(z)-ln(-1))**2 + 16))*(-I*(z+1)/(z-1)+2*I*sqrt(z)/(z-1))
fz
# Out:
# (2*I*sqrt(z)/(z - 1) - I*(z + 1)/(z - 1))*(-1/(16 - (log(z) + I*pi)**2) + 1/(16 - (log(z) - I*pi)**2))

# %%
fz2 = (-1/(-(ln(z)+ln(-1))**2 + 16) + 1/(-(ln(z)-ln(-1))**2 + 16))*(-(z+1)/(z-1)/z+2*sqrt(z)/(z-1)/z)
fz2a = (-1/(-(ln(z)+ln(-1))**2 + 16) + 1/(-(ln(z)-ln(-1))**2 + 16))
fz2b = (-(z+1)/(z-1)/z+2*sqrt(z)/(z-1)/z)
fz2
# Out:
# ((-z - 1)/(z*(z - 1)) + 2/(sqrt(z)*(z - 1)))*(-1/(16 - (log(z) + I*pi)**2) + 1/(16 - (log(z) - I*pi)**2))

# %%
Eq(1/(tau**2-(log(z)+I*pi)**2),1/(tau-(log(z)+I*pi))/tau/2+1/(tau+(log(z)+I*pi))/tau/2)
# Out:
# Eq(1/(tau**2 - (log(z) + I*pi)**2), 1/(2*tau*(tau + log(z) + I*pi)) + 1/(2*tau*(tau - log(z) - I*pi)))

# %%
Eq(1/(tau**2-(log(z)+I*pi)**2),1/(tau-(log(z)+I*pi))/tau/2+1/(tau+(log(z)+I*pi))/tau/2).subs(I,-I)
# Out:
# Eq(1/(tau**2 - (log(z) - I*pi)**2), 1/(2*tau*(tau + log(z) - I*pi)) + 1/(2*tau*(tau - log(z) + I*pi)))

# %%
limit(ln(exp(-I*pi*epsilon)),epsilon,0.99)
# Out:
# -0.99*I*pi

# %%
solve(tau-(log(z)+I*pi),z)
# Out:
# [-exp(tau)]

# %%
solve(tau+(log(z)+I*pi),z)
# Out:
# [-exp(-tau)]

# %%
solve(tau+(log(z)-I*pi),z)
# Out:
# [-exp(-tau)]

# %%
solve(tau-(log(z)-I*pi),z)
# Out:
# [-exp(tau)]

# %%
2*pi*I*limit(fz2*(z+exp(-4)),z,-exp(-4)).simplify()
# Out:
# I*pi*(exp(2) - I)/(4*(exp(2) + I))

# %%
(2*pi*I*limit(fz2*(z+exp(-4)),z,-exp(-4)).simplify()).evalf()
# Out:
# 0.208760582353234 + 0.757145490856033*I

# %%
fz2.subs(z,-exp(-4))
# Out:
# (zoo - 1/(16 - (-4 + 2*I*pi)**2))*(-(-1 + exp(-4))*exp(4)/(-1 - exp(-4)) - 2*I*exp(2)/(-1 - exp(-4)))

# %%
-exp(-16).evalf()
# Out:
# -1.12535174719259e-7

# %%
Integral(fz2,z)
# Out:
# Integral(((-z - 1)/(z*(z - 1)) + 2/(sqrt(z)*(z - 1)))*(-1/(16 - (log(z) + I*pi)**2) + 1/(16 - (log(z) - I*pi)**2)), z)

# %%
part1_unit = Integral(fz2.subs(z,x+I*epsilon),(x,-1,0))
part1_unit
# Out:
# Integral(((-I*epsilon - x - 1)/((I*epsilon + x)*(I*epsilon + x - 1)) + 2/(sqrt(I*epsilon + x)*(I*epsilon + x - 1)))*(-1/(16 - (log(I*epsilon + x) + I*pi)**2) + 1/(16 - (log(I*epsilon + x) - I*pi)**2)), (x, -1, 0))

# %%
part2_unit = Integral(fz2.subs(z,x-I*epsilon),(x,0,-1))
part2_unit
# Out:
# Integral(((I*epsilon - x - 1)/((-I*epsilon + x)*(-I*epsilon + x - 1)) + 2/(sqrt(-I*epsilon + x)*(-I*epsilon + x - 1)))*(-1/(16 - (log(-I*epsilon + x) + I*pi)**2) + 1/(16 - (log(-I*epsilon + x) - I*pi)**2)), (x, 0, -1))

# %%
Eq(arg(x+I*epsilon),atan2(epsilon,x)).subs([(x,-0.5),(epsilon,0.1)])
# Out:
# True

# %%
Eq(arg(x+I*epsilon),atan2(epsilon,x)).subs([(x,-0.5),(epsilon,0.1)])

# %%
Eq(arg(x+I*epsilon), atan(epsilon/x) + pi).subs([(x,-0.5),(epsilon,0.1)])
# Out:
# True

# %%
sqrt(abs(x))*exp(I*pi/2)
# Out:
# I*sqrt(Abs(x))

# %%
Eq(arg(x-I*epsilon), -atan(epsilon/x) - pi).subs([(x,-0.5),(epsilon,0.1)])
# Out:
# True

# %%
sqrt(abs(x))*exp(-I*pi/2)
# Out:
# -I*sqrt(Abs(x))

# %%
limit(sqrt(-1/2-I*epsilon),epsilon,0)
# Out:
# -0.707106781186548*I

# %%
limit(ln(-1/2-I*epsilon),epsilon,0)
# Out:
# -0.693147180559945 - I*pi

# %%
limit(ln(-1/2+I*epsilon),epsilon,0)
# Out:
# -0.693147180559945 + I*pi

# %%
ln(1/2)
# Out:
# -0.693147180559945

# %%
atan(-epsilon/x)
# Out:
# -atan(epsilon/x)

# %%
diff(sqrt(z),z)
# Out:
# 1/(2*sqrt(z))

# %%
Eq(1/(alpha**2-beta**2),1/alpha/2*(1/(alpha-beta)+1/(alpha+beta)))
# Out:
# Eq(1/(alpha**2 - beta**2), (1/(alpha + beta) + 1/(alpha - beta))/(2*alpha))

# %%
from sympy.plotting import plot3d
plot3d(abs(fz2.subs(z,x+I*y)),(x, -1, 1), (y, -1, 1))

# %%
from sympy.plotting import plot3d
plot3d(abs(((z+exp(-4))*fz2a).subs(z,x+I*y)),(x, -0.05, 0.05), (y, -0.05, 0.05))

# %%
from sympy.plotting import plot3d
plot3d(abs((z*fz2b).subs(z,x+I*y)),(x, -1, 1), (y, -1, 1))

# %%
Eq(z,exp(I*x))
# Out:
# Eq(z, exp(I*x))

# %%
diff(exp(I*x),x)
# Out:
# I*exp(I*x)

# %%
Integral(fz2.subs(z,exp(I*x))*I*exp(I*x),(x,-pi,pi))
# Out:
# Integral(I*((-exp(I*x) - 1)*exp(-I*x)/(exp(I*x) - 1) + 2/((exp(I*x) - 1)*sqrt(exp(I*x))))*(-1/(16 - (log(exp(I*x)) + I*pi)**2) + 1/(16 - (log(exp(I*x)) - I*pi)**2))*exp(I*x), (x, -pi, pi))

# %%
fz3 = (
I*((-exp(I*x)-1)/(exp(I*x)-1) + 2*exp(I*x)/(exp(I*x)-1)/exp(I*x/2)).simplify()*(-1/(16-(I*x+I*pi)**2)+1/(16-(I*x-I*pi)**2))
)
fz3
# Out:
# -I*(-1/(16 - (I*x + I*pi)**2) + 1/(16 - (I*x - I*pi)**2))*(-2*exp(I*x/2) + exp(I*x) + 1)/(exp(I*x) - 1)

# %%
Integral(fz3,(x,-pi,pi)).evalf()
# Out:
# 0.0954393985248599 + 0.e-35*I

# %%
Integral(fz2.subs(z,exp(I*x))*I*exp(I*x),(x,-pi+0.1,pi-0.1)).evalf()
# Out:
# 0.e-1 + 0.e+9*I

# %%
plot(abs(fz2.subs(z,exp(I*x))*I*exp(I*x).simplify()-(1/(16+(x-pi)**2)-1/(16+(x+pi)**2))*tan(x/4)),(x,-pi,pi))

# %%
Integral(fz2.subs(z,exp(I*x))*I*exp(I*x),(x,-pi,pi)).evalf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-64f564b9e813> in <module>
# ----> 1 Integral(fz2.subs(z,exp(I*x))*I*exp(I*x),(x,-pi,pi)).evalf()
#
# ~/.local/lib/python3.8/site-packages/sympy/core/evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1512             options['quad'] = quad
#    1513         try:
# -> 1514             result = evalf(self, prec + 4, options)
#    1515         except NotImplementedError:
#    1516             # Fall back to the ordinary evalf
#
# ~/.local/lib/python3.8/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1364     try:
#    1365         rf = evalf_table[x.func]
# -> 1366         r = rf(x, prec, options)
#    1367     except KeyError:
#    1368         # Fall back to ordinary evalf if possible
#
# ...

# %%
plot(fz.subs(z,exp(I*x))-(1/(16+(x-pi)**2)-1/(16+(x+pi)**2))*tan(x/4),(x,-pi,pi))

# %%
(atan(pi/2)/2 + Integral((1/(16+(x-pi)**2)-1/(16+(x+pi)**2))*tan(x/4),(x,-pi,pi))).evalf()
# Out:
# 0.597381809451804

# %%
Eq(tan(x/4),1/sin(x/2)-cot(x/2))
# Out:
# Eq(tan(x/4), -cot(x/2) + 1/sin(x/2))

# %%
(1/sin(x/2) - cot(x/2)).rewrite(exp)
# Out:
# -I*(exp(I*x/2) + exp(-I*x/2))/(exp(I*x/2) - exp(-I*x/2)) + 2*I/(exp(I*x/2) - exp(-I*x/2))

# %%
Eq(tan(x/4),-I*(exp(I*x)+1)/(exp(I*x)-1)+2*I*exp(I*x/2)/(exp(I*x)-1))
# Out:
# Eq(tan(x/4), -I*(exp(I*x) + 1)/(exp(I*x) - 1) + 2*I*exp(I*x/2)/(exp(I*x) - 1))

# %%
Eq(tan(x/4),(1/sin(x/2)-cot(x/2)).rewrite(exp)).subs(x,pi/2).evalf()
# Out:
# False

# %%
Eq(tan(x/4),1/sin(x/2)-cot(x/2)).subs(x,pi/4)
# Out:
# True

# %%
plot(tan(x/4) - 1/sin(x/2)+ cot(x/2),(x,-pi,pi))

# %%
Eq(cot(x/2),1/(-cot(x)+1/sin(x))).simplify()
# Out:
# Eq(cot(x/2), -sin(x)/(cos(x) - 1))

# %%
Eq(cot(x/2),1/(-cot(x)+1/sin(x))).subs(x,pi/4)
# Out:
# True

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,pi/4,pi/2))
# Out:
# Integral((-1/(2*((x + pi/4)**2 + 1)) + 1/(2*((x - pi/4)**2 + 1)))*tan(x), (x, pi/4, pi/2))

# %%
Integral(((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x)).subs(x,x+pi/4),(x,0,pi/4))
# Out:
# Integral((-1/(2*((x + pi/2)**2 + 1)) + 1/(2*(x**2 + 1)))*tan(x + pi/4), (x, 0, pi/4))

# %%
Integral((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x),(x,-pi/2, -pi/4))
# Out:
# Integral((-1/(2*((x + pi/4)**2 + 1)) + 1/(2*((x - pi/4)**2 + 1)))*tan(x), (x, -pi/2, -pi/4))

# %%
Integral(((1/(1+(x-pi/4)**2)/2-1/(1+(x+pi/4)**2)/2)*tan(x)).subs(x,x-pi/4),(x,-pi/4,0))
# Out:
# Integral(-(1/(2*((x - pi/2)**2 + 1)) - 1/(2*(x**2 + 1)))*cot(x + pi/4), (x, -pi/4, 0))

# %%
Eq(tan(x + pi/4), 1/cos(2*x) + tan(2*x))
# Out:
# Eq(tan(x + pi/4), tan(2*x) + 1/cos(2*x))

# %%
Eq(tan(x - pi/4), 1/cos(2*x) - tan(2*x))
# Out:
# Eq(-cot(x + pi/4), -tan(2*x) + 1/cos(2*x))

# %%
Eq(tan(x + pi/4), 1/cos(2*x) +  tan(2*x)).subs(x,pi/3)
# Out:
# True
